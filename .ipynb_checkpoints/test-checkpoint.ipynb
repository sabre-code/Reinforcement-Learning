# %%
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor
import os

# %%
environment_name = 'CarRacing-v0'
env = gym.make(environment_name)

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])

# %%
env.action_space
# Out:
# Box([-1.  0.  0.], [1. 1. 1.], (3,), float32)

# %%
env.reset()

# %%
ppo_path = os.path.join('Training','Saved Models', 'PPO_2m_Driving_model')

# %%
ppo_path = os.path.join('Training','Saved Models', 'PPO_DrivingX_570k')

# %%
ppo_path = os.path.join('Training','Saved Models', 'PPO_Driving_2M')

# %%
model = PPO.load(ppo_path,env)
# Out:
# Wrapping the env in a VecTransposeImage.

# %%
del model

# %%
log_path = os.path.join('Training','Logs')
model = PPO('CnnPolicy',env,verbose=1,tensorboard_log=log_path)
#model = PPO('CnnPolicy',env,verbose=1)
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=600000)
# Out:
# Track generation: 1124..1409 -> 285-tiles track
# Logging to Training\Logs\PPO_34
# Track generation: 1194..1497 -> 303-tiles track
# Track generation: 1130..1417 -> 287-tiles track
# -----------------------------
# | time/              |      |
# |    fps             | 18   |
# |    iterations      | 1    |
# |    time_elapsed    | 108  |
# |    total_timesteps | 2048 |
# -----------------------------
# Track generation: 1203..1508 -> 305-tiles track
# Track generation: 1043..1315 -> 272-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 2           |
# |    time_elapsed         | 238         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.005646497 |
# |    clip_fraction        | 0.0506      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.23       |
# ...

# %%
ppo_path = os.path.join('Training','Saved Models', 'PPO_DrivingX_600kfin')
model.save(ppo_path)

# %%
evaluate_policy(model,env,n_eval_episodes=1,render=True)
# Out:
# Track generation: 1259..1584 -> 325-tiles track

# %%
env.close()
